# %%
from google.colab import drive

drive.mount('/content/gdrive')

import sys

# !ls /content/gdrive/MyDrive/Colab\ Notebooks

sys.path.append('/content/gdrive/MyDrive/Colab Notebooks/L2D-reinforcement_learning/lib')
# Out:
# Mounted at /content/gdrive
# agents_nt.py					L2D-reinforcement_learning
# BIOS0040-CPS-10-frozen-lake.ipynb		__pycache__
# BIOS0040-CPS-10-frozen-lake_solution.ipynb	utils_nt.py
# BIOS0040-Week-10-practical-cliff-walking.ipynb	W10_lecture1.pptx

# %%
# !pip install gymnasium[toy_text]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gymnasium[toy_text]
#   Downloading gymnasium-0.27.1-py3-none-any.whl (883 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 KB 32.2 MB/s eta 0:00:00
# Collecting jax-jumpy>=0.2.0
#   Downloading jax_jumpy-0.2.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.8/dist-packages (from gymnasium[toy_text]) (1.21.6)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.8/dist-packages (from gymnasium[toy_text]) (2.2.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.8/dist-packages (from gymnasium[toy_text]) (4.4.0)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /usr/local/lib/python3.8/dist-packages (from gymnasium[toy_text]) (6.0.0)
# Collecting gymnasium-notices>=0.0.1
#   Downloading gymnasium_notices-0.0.1-py3-none-any.whl (2.8 kB)
# Collecting pygame==2.1.3.dev8
#   Downloading pygame-2.1.3.dev8-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 68.5 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.8.0->gymnasium[toy_text]) (3.11.0)
# Installing collected packages: gymnasium-notices, pygame, jax-jumpy, gymnasium
# Successfully installed gymnasium-0.27.1 gymnasium-notices-0.0.1 jax-jumpy-0.2.0 pygame-2.1.3.dev8

# %%
# !apt-get install x11-utils > /dev/null 2>&1 
# !pip install pyglet > /dev/null 2>&1 
# !apt-get install -y xvfb python-opengl > /dev/null 2>&1
# !pip install pyvirtualdisplay > /dev/null 2>&1

# %%
import gymnasium as gym
import sys
import os

from utils_nt import plot_value, plot_returns, plot_explore, train_agent
from bioreactor_env_nt import BioreactorEnv, xdot_control, target_reward
import numpy as np
import matplotlib.pyplot as plt
import math

from pyvirtualdisplay import Display
from IPython import display as ipythondisplay
import time

# %% [markdown]
# ## 1.

# %%
class Q_agent():

    def __init__(self, n_states, n_actions, gamma = 0.95, alpha = 0.01):

        self.gamma = gamma
        self.alpha = alpha
        self.n_states = n_states
        self.n_actions = n_actions
        self.Q_func = np.zeros((n_states, n_actions))


    def policy(self, state, explore_rate):
        '''
        chooses an action based on the agents value function and the current explore rate
        :param state: the current state given by the environment
        :param explore_rate: the chance of taking a random action
        :return: the action to be taken
        '''


        if np.random.random() < explore_rate:
            action = np.random.choice(range(self.n_actions))
        else:
            action = np.argmax(self.Q_func[state])

        return action
    
    def update_Q(self,transition):
        '''
        updates the agents value function based on the experience in transition
        :param transition:
        :return:
        '''
        state, action, reward, next_state, next_action, done = transition

        self.Q_func[state, action] += self.alpha * (reward + self.gamma * np.max(self.Q_func[next_state]) * (1 - done) - self.Q_func[state, action])

    def get_explore_rate(self, episode, decay, min_r = 0, max_r = 1):
        '''
        Calculates the logarithmically decreasing explore or learning rate

        Parameters:
            episode: the current episode
            MIN_LEARNING_RATE: the minimum possible step size
            MAX_LEARNING_RATE: maximum step size
            denominator: controls the rate of decay of the step size
        Returns:
            step_size: the Q-learning step size
        '''

        rate = max(min_r, min(max_r, 1.0 - math.log10((episode + 1) / decay)))

        return rate

# %% [markdown]
# # 2.

# %%
env = gym.make('FrozenLake-v1', render_mode = 'rgb_array', desc=None, map_name="4x4", is_slippery=False)


n_states = 16
n_actions = 4
grid_shape = (4,4)
p_map = {0:'L', 1:'D', 2:'R', 3:'U'}

agent = Q_agent(n_states, n_actions)
n_episodes = 10001

print('TRAINING')
returns = train_agent(agent, env, n_episodes = n_episodes) # train the agent
print()
# Out:
# TRAINING
# episode: 0 , explore_rate: 1 , return: 0.0
# episode: 100 , explore_rate: 1 , return: 0.0
# episode: 200 , explore_rate: 1 , return: 0.0
# episode: 300 , explore_rate: 1 , return: 0.0
# episode: 400 , explore_rate: 1 , return: 0.0
# episode: 500 , explore_rate: 1 , return: 0.0
# episode: 600 , explore_rate: 1 , return: 0.0
# episode: 700 , explore_rate: 1 , return: 0.0
# episode: 800 , explore_rate: 1 , return: 0.0
# episode: 900 , explore_rate: 1 , return: 0.0
# episode: 1000 , explore_rate: 0.958216664639319 , return: 0.0
# episode: 1100 , explore_rate: 0.9168634231468858 , return: 0.0
# episode: 1200 , explore_rate: 0.8791077347157316 , return: 0.0
# episode: 1300 , explore_rate: 0.8443734455570514 , return: 0.0
# episode: 1400 , explore_rate: 0.812212606832863 , return: 0.0
# episode: 1500 , explore_rate: 0.7822700498753672 , return: 0.0
# episode: 1600 , explore_rate: 0.7542594101993378 , return: 1.0
# episode: 1700 , explore_rate: 0.7279464285060686 , return: 0.0
# episode: 1800 , explore_rate: 0.7031370292991043 , return: 0.0
# episode: 1900 , explore_rate: 0.6796686252531945 , return: 1.0
# episode: 2000 , explore_rate: 0.6574036534824262 , return: 1.0
# episode: 2100 , explore_rate: 0.6362246897126851 , return: 0.0
# episode: 2200 , explore_rate: 0.6160306995652897 , return: 0.0
# episode: 2300 , explore_rate: 0.5967341234499942 , return: 0.0
# episode: 2400 , explore_rate: 0.5782585820616103 , return: 0.0
# episode: 2500 , explore_rate: 0.5605370503881351 , return: 0.0
# episode: 2600 , explore_rate: 0.5435103899227649 , return: 0.0
# episode: 2700 , explore_rate: 0.5271261579311868 , return: 1.0
# episode: 2800 , explore_rate: 0.5113376332950694 , return: 0.0
# episode: 2900 , explore_rate: 0.4961030133159735 , return: 1.0
# episode: 3000 , explore_rate: 0.48138474669378506 , return: 0.0
# episode: 3100 , explore_rate: 0.4671489758813112 , return: 0.0
# episode: 3200 , explore_rate: 0.45336506797450526 , return: 1.0
# episode: 3300 , explore_rate: 0.440005217788326 , return: 0.0
# episode: 3400 , explore_rate: 0.4270441101859155 , return: 0.0
# episode: 3500 , explore_rate: 0.41445863135360494 , return: 1.0
# episode: 3600 , explore_rate: 0.4022276207473523 , return: 1.0
# episode: 3700 , explore_rate: 0.3903316570235258 , return: 1.0
# episode: 3800 , explore_rate: 0.3787528725155339 , return: 0.0
# episode: 3900 , explore_rate: 0.3674747918068463 , return: 0.0
# episode: 4000 , explore_rate: 0.3564821907396405 , return: 0.0
# episode: 4100 , explore_rate: 0.3457609728311529 , return: 1.0
# episode: 4200 , explore_rate: 0.3352980605806456 , return: 0.0
# episode: 4300 , explore_rate: 0.3250812995645458 , return: 1.0
# episode: 4400 , explore_rate: 0.3150993735556925 , return: 0.0
# episode: 4500 , explore_rate: 0.30534172918015867 , return: 0.0
# episode: 4600 , explore_rate: 0.2957985088538414 , return: 0.0
# episode: 4700 , explore_rate: 0.28646049093038506 , return: 1.0
# episode: 4800 , explore_rate: 0.27731903614947184 , return: 0.0
# episode: 4900 , explore_rate: 0.268366039606008 , return: 1.0
# episode: 5000 , explore_rate: 0.2595938875709698 , return: 0.0
# episode: 5100 , explore_rate: 0.25099541858745067 , return: 1.0
# episode: 5200 , explore_rate: 0.2425638883438055 , return: 0.0
# episode: 5300 , explore_rate: 0.23429293789221106 , return: 1.0
# episode: 5400 , explore_rate: 0.22617656483744408 , return: 1.0
# episode: 5500 , explore_rate: 0.2182090971688716 , return: 1.0
# episode: 5600 , explore_rate: 0.21038516944989683 , return: 0.0
# episode: 5700 , explore_rate: 0.20269970111450564 , return: 1.0
# episode: 5800 , explore_rate: 0.1951478766510406 , return: 1.0
# episode: 5900 , explore_rate: 0.18772512747963843 , return: 1.0
# episode: 6000 , explore_rate: 0.18042711535254108 , return: 1.0
# episode: 6100 , explore_rate: 0.17324971712625004 , return: 1.0
# episode: 6200 , explore_rate: 0.1661890107716869 , return: 1.0
# episode: 6300 , explore_rate: 0.15924126250351078 , return: 1.0
# episode: 6400 , explore_rate: 0.1524029149228472 , return: 1.0
# episode: 6500 , explore_rate: 0.14567057607915723 , return: 1.0
# episode: 6600 , explore_rate: 0.13904100936705244 , return: 1.0
# episode: 6700 , explore_rate: 0.13251112418272282 , return: 1.0
# episode: 6800 , explore_rate: 0.12607796727245768 , return: 1.0
# episode: 6900 , explore_rate: 0.11973871471263897 , return: 1.0
# episode: 7000 , explore_rate: 0.11349066446669176 , return: 1.0
# episode: 7100 , explore_rate: 0.10733122946989249 , return: 1.0
# episode: 7200 , explore_rate: 0.1012579311977363 , return: 1.0
# episode: 7300 , explore_rate: 0.0952683936778499 , return: 1.0
# episode: 7400 , explore_rate: 0.08936033790923914 , return: 1.0
# episode: 7500 , explore_rate: 0.08353157665606947 , return: 1.0
# episode: 7600 , explore_rate: 0.07778000958621412 , return: 1.0
# episode: 7700 , explore_rate: 0.07210361872753179 , return: 1.0
# episode: 7800 , explore_rate: 0.06650046421727351 , return: 0.0
# episode: 7900 , explore_rate: 0.060968680322217694 , return: 1.0
# episode: 8000 , explore_rate: 0.05550647170909906 , return: 1.0
# episode: 8100 , explore_rate: 0.05011210994667814 , return: 1.0
# episode: 8200 , explore_rate: 0.04478393022239835 , return: 1.0
# episode: 8300 , explore_rate: 0.03952032825802321 , return: 1.0
# episode: 8400 , explore_rate: 0.034319757409959184 , return: 1.0
# episode: 8500 , explore_rate: 0.029180725941148067 , return: 1.0
# episode: 8600 , explore_rate: 0.02410179445249072 , return: 1.0
# episode: 8700 , explore_rate: 0.01908157346273598 , return: 1.0
# episode: 8800 , explore_rate: 0.014118721126656464 , return: 1.0
# episode: 8900 , explore_rate: 0.009211941082133412 , return: 1.0
# episode: 9000 , explore_rate: 0.004359980417510623 , return: 1.0
# episode: 9100 , explore_rate: 0 , return: 1.0
# episode: 9200 , explore_rate: 0 , return: 1.0
# episode: 9300 , explore_rate: 0 , return: 1.0
# episode: 9400 , explore_rate: 0 , return: 1.0
# episode: 9500 , explore_rate: 0 , return: 1.0
# episode: 9600 , explore_rate: 0 , return: 1.0
# episode: 9700 , explore_rate: 0 , return: 1.0
# episode: 9800 , explore_rate: 0 , return: 1.0
# episode: 9900 , explore_rate: 0 , return: 1.0
# episode: 10000 , explore_rate: 0 , return: 1.0

# %%
print('TEST EPISODE')
train_agent(agent, env, n_episodes=1,display=True, simple_text = True) # run a test episode to get the learned behaviour with no exploring

plot_value(agent.Q_func, grid_shape, p_map) # plot the value function and policy 
plot_returns(returns)
plot_explore(agent.get_explore_rate, n_episodes)

# %% [markdown]
# # 4.

# %%
class SARSA_agent():

    def __init__(self, n_states, n_actions, gamma = 0.95, alpha = 0.01):

        self.gamma = gamma
        self.alpha = alpha
        self.n_states = n_states
        self.n_actions = n_actions
        self.Q_func = np.zeros((n_states, n_actions))


    def policy(self, state, explore_rate):
        '''
        chooses an action based on the agents value function and the current explore rate
        :param state: the current state given by the environment
        :param explore_rate: the chance of taking a random action
        :return: the action to be taken
        '''


        if np.random.random() < explore_rate:
            action = np.random.choice(range(self.n_actions))
        else:
            action = np.argmax(self.Q_func[state])

        return action
    
    def update_Q(self,transition):
        '''
        updates the agents value function based on the experience in transition
        :param transition:
        :return:
        '''

        state, action, reward, next_state, next_action, done = transition

        self.Q_func[state, action] += self.alpha * (reward + self.gamma * self.Q_func[next_state,next_action] * (1 - done) - self.Q_func[state, action])

    def get_explore_rate(self, episode, decay, min_r = 0, max_r = 1):
        '''
        Calculates the logarithmically decreasing explore or learning rate

        Parameters:
            episode: the current episode
            MIN_LEARNING_RATE: the minimum possible step size
            MAX_LEARNING_RATE: maximum step size
            denominator: controls the rate of decay of the step size
        Returns:
            step_size: the Q-learning step size
        '''

        rate = max(min_r, min(max_r, 1.0 - math.log10((episode + 1) / decay)))

        return rate

# %%
agent = SARSA_agent(n_states, n_actions)
n_episodes = 10001

print('TRAINING')
returns = train_agent(agent, env, n_episodes = n_episodes) # train the agent
print()
# Out:
# TRAINING
# episode: 0 , explore_rate: 1 , return: 0.0
# episode: 100 , explore_rate: 1 , return: 0.0
# episode: 200 , explore_rate: 1 , return: 0.0
# episode: 300 , explore_rate: 1 , return: 0.0
# episode: 400 , explore_rate: 1 , return: 0.0
# episode: 500 , explore_rate: 1 , return: 0.0
# episode: 600 , explore_rate: 1 , return: 0.0
# episode: 700 , explore_rate: 1 , return: 0.0
# episode: 800 , explore_rate: 1 , return: 0.0
# episode: 900 , explore_rate: 1 , return: 0.0
# episode: 1000 , explore_rate: 0.958216664639319 , return: 0.0
# episode: 1100 , explore_rate: 0.9168634231468858 , return: 0.0
# episode: 1200 , explore_rate: 0.8791077347157316 , return: 0.0
# episode: 1300 , explore_rate: 0.8443734455570514 , return: 0.0
# episode: 1400 , explore_rate: 0.812212606832863 , return: 0.0
# episode: 1500 , explore_rate: 0.7822700498753672 , return: 0.0
# episode: 1600 , explore_rate: 0.7542594101993378 , return: 0.0
# episode: 1700 , explore_rate: 0.7279464285060686 , return: 0.0
# episode: 1800 , explore_rate: 0.7031370292991043 , return: 1.0
# episode: 1900 , explore_rate: 0.6796686252531945 , return: 0.0
# episode: 2000 , explore_rate: 0.6574036534824262 , return: 1.0
# episode: 2100 , explore_rate: 0.6362246897126851 , return: 0.0
# episode: 2200 , explore_rate: 0.6160306995652897 , return: 1.0
# episode: 2300 , explore_rate: 0.5967341234499942 , return: 0.0
# episode: 2400 , explore_rate: 0.5782585820616103 , return: 0.0
# episode: 2500 , explore_rate: 0.5605370503881351 , return: 0.0
# episode: 2600 , explore_rate: 0.5435103899227649 , return: 0.0
# episode: 2700 , explore_rate: 0.5271261579311868 , return: 0.0
# episode: 2800 , explore_rate: 0.5113376332950694 , return: 0.0
# episode: 2900 , explore_rate: 0.4961030133159735 , return: 0.0
# episode: 3000 , explore_rate: 0.48138474669378506 , return: 0.0
# episode: 3100 , explore_rate: 0.4671489758813112 , return: 0.0
# episode: 3200 , explore_rate: 0.45336506797450526 , return: 0.0
# episode: 3300 , explore_rate: 0.440005217788326 , return: 0.0
# episode: 3400 , explore_rate: 0.4270441101859155 , return: 1.0
# episode: 3500 , explore_rate: 0.41445863135360494 , return: 0.0
# episode: 3600 , explore_rate: 0.4022276207473523 , return: 0.0
# episode: 3700 , explore_rate: 0.3903316570235258 , return: 1.0
# episode: 3800 , explore_rate: 0.3787528725155339 , return: 1.0
# episode: 3900 , explore_rate: 0.3674747918068463 , return: 0.0
# episode: 4000 , explore_rate: 0.3564821907396405 , return: 1.0
# episode: 4100 , explore_rate: 0.3457609728311529 , return: 1.0
# episode: 4200 , explore_rate: 0.3352980605806456 , return: 0.0
# episode: 4300 , explore_rate: 0.3250812995645458 , return: 1.0
# episode: 4400 , explore_rate: 0.3150993735556925 , return: 0.0
# episode: 4500 , explore_rate: 0.30534172918015867 , return: 1.0
# episode: 4600 , explore_rate: 0.2957985088538414 , return: 1.0
# episode: 4700 , explore_rate: 0.28646049093038506 , return: 1.0
# episode: 4800 , explore_rate: 0.27731903614947184 , return: 0.0
# episode: 4900 , explore_rate: 0.268366039606008 , return: 1.0
# episode: 5000 , explore_rate: 0.2595938875709698 , return: 1.0
# episode: 5100 , explore_rate: 0.25099541858745067 , return: 1.0
# episode: 5200 , explore_rate: 0.2425638883438055 , return: 1.0
# episode: 5300 , explore_rate: 0.23429293789221106 , return: 1.0
# episode: 5400 , explore_rate: 0.22617656483744408 , return: 1.0
# episode: 5500 , explore_rate: 0.2182090971688716 , return: 1.0
# episode: 5600 , explore_rate: 0.21038516944989683 , return: 1.0
# episode: 5700 , explore_rate: 0.20269970111450564 , return: 1.0
# episode: 5800 , explore_rate: 0.1951478766510406 , return: 1.0
# episode: 5900 , explore_rate: 0.18772512747963843 , return: 1.0
# episode: 6000 , explore_rate: 0.18042711535254108 , return: 1.0
# episode: 6100 , explore_rate: 0.17324971712625004 , return: 1.0
# episode: 6200 , explore_rate: 0.1661890107716869 , return: 0.0
# episode: 6300 , explore_rate: 0.15924126250351078 , return: 1.0
# episode: 6400 , explore_rate: 0.1524029149228472 , return: 1.0
# episode: 6500 , explore_rate: 0.14567057607915723 , return: 1.0
# episode: 6600 , explore_rate: 0.13904100936705244 , return: 1.0
# episode: 6700 , explore_rate: 0.13251112418272282 , return: 1.0
# episode: 6800 , explore_rate: 0.12607796727245768 , return: 1.0
# episode: 6900 , explore_rate: 0.11973871471263897 , return: 1.0
# episode: 7000 , explore_rate: 0.11349066446669176 , return: 1.0
# episode: 7100 , explore_rate: 0.10733122946989249 , return: 0.0
# episode: 7200 , explore_rate: 0.1012579311977363 , return: 0.0
# episode: 7300 , explore_rate: 0.0952683936778499 , return: 0.0
# episode: 7400 , explore_rate: 0.08936033790923914 , return: 1.0
# episode: 7500 , explore_rate: 0.08353157665606947 , return: 1.0
# episode: 7600 , explore_rate: 0.07778000958621412 , return: 1.0
# episode: 7700 , explore_rate: 0.07210361872753179 , return: 1.0
# episode: 7800 , explore_rate: 0.06650046421727351 , return: 1.0
# episode: 7900 , explore_rate: 0.060968680322217694 , return: 1.0
# episode: 8000 , explore_rate: 0.05550647170909906 , return: 1.0
# episode: 8100 , explore_rate: 0.05011210994667814 , return: 1.0
# episode: 8200 , explore_rate: 0.04478393022239835 , return: 1.0
# episode: 8300 , explore_rate: 0.03952032825802321 , return: 1.0
# episode: 8400 , explore_rate: 0.034319757409959184 , return: 1.0
# episode: 8500 , explore_rate: 0.029180725941148067 , return: 1.0
# episode: 8600 , explore_rate: 0.02410179445249072 , return: 1.0
# episode: 8700 , explore_rate: 0.01908157346273598 , return: 1.0
# episode: 8800 , explore_rate: 0.014118721126656464 , return: 1.0
# episode: 8900 , explore_rate: 0.009211941082133412 , return: 1.0
# episode: 9000 , explore_rate: 0.004359980417510623 , return: 1.0
# episode: 9100 , explore_rate: 0 , return: 1.0
# episode: 9200 , explore_rate: 0 , return: 1.0
# episode: 9300 , explore_rate: 0 , return: 1.0
# episode: 9400 , explore_rate: 0 , return: 1.0
# episode: 9500 , explore_rate: 0 , return: 1.0
# episode: 9600 , explore_rate: 0 , return: 1.0
# episode: 9700 , explore_rate: 0 , return: 1.0
# episode: 9800 , explore_rate: 0 , return: 1.0
# episode: 9900 , explore_rate: 0 , return: 1.0
# episode: 10000 , explore_rate: 0 , return: 1.0

# %%
print('TEST EPISODE')
train_agent(agent, env, n_episodes=1, display=True, simple_text = True) # run a test episode to get the learned behaviour with no exploring

plot_value(agent.Q_func, grid_shape, p_map) # plot the value function and policy 
plot_returns(returns)
plot_explore(agent.get_explore_rate, n_episodes)

# %%
num_controlled_species = 1

sampling_time = 5  # minutes
n_episodes = 1001

t_steps = int((24 * 60) / sampling_time)  # set this to 24 hours

target_pop = 35000

reward_f = lambda x: target_reward(x, target_pop)


initial_x = np.array([20000, 0, 1])  # the initial state

env = BioreactorEnv(xdot_control, reward_f, sampling_time,
                    num_controlled_species, initial_x, t_steps)  # initalise the chemostat environment



n_states = 10
n_actions = 2
agent = Q_agent(n_states, n_actions)


returns = train_agent(agent, env, n_episodes= n_episodes)
# Out:
# episode: 0 , explore_rate: 1 , return: -4.868893095431279
# episode: 100 , explore_rate: 0.954720018538451 , return: -4.370203380806927
# episode: 200 , explore_rate: 0.6558453349006047 , return: -1.4977952560616687
# episode: 300 , explore_rate: 0.4804748967272503 , return: -0.763255959531765
# episode: 400 , explore_rate: 0.35589701970091125 , return: -0.5653278524183156
# episode: 500 , explore_rate: 0.25920366645384785 , return: -0.5250861396083861
# episode: 600 , explore_rate: 0.18016692031835402 , return: -0.5210091845077
# episode: 700 , explore_rate: 0.11332337435443496 , return: -0.37828545047733403
# episode: 800 , explore_rate: 0.055408876236855864 , return: -0.362755027408332
# episode: 900 , explore_rate: 0.0043166013420306015 , return: -0.3507113079394339
# episode: 1000 , explore_rate: 0 , return: -0.3507113079394339

# %%
# plot results
fig, ax1 = plt.subplots()

plt.plot(returns, label='Return')
explore_rates = [agent.get_explore_rate(episode, n_episodes / 11) for episode in range(n_episodes)]
ax1.set_ylabel('Return')
ax1.set_xlabel('Episode')
ax2 = ax1.twinx()
ax2.plot(explore_rates, color='black', label='Explore rate')
ax2.set_ylabel('Explore Rate')
ax2.set_xlabel('Episode')
plt.tight_layout()
ax1.legend(loc=(0.21, 0.67))
ax2.legend(loc=(0.6, 0.22))

plt.figure()
plt.title('Final population curve')
plt.plot(np.arange(len(env.xs)) * sampling_time, [x[0] for x in env.xs], label='population')
plt.hlines(target_pop, 0, len(env.xs)* sampling_time, label='target', color='r')
plt.legend()
plt.xlabel('Time (hours)')
plt.ylabel('Population cells/L')

plt.figure()
plt.title('Actions')
plt.step(np.arange(len(env.us)) * sampling_time, [x[0] for x in env.us])

plt.xlabel('Time (hours)')
plt.ylabel('$C_{in}$')

plt.show()
